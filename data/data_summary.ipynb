# %%
import pandas as pd

# %%
structure_energies = pd.read_csv('structure_energies.csv',header=4)
structure_energies
# Out:
#                Model   fGln123     Val51 Structure  Geom opt (Hartee)  \
# 0           Inactive  Inactive  Inactive        ES          -5709.932
# 1           Inactive  Inactive  Inactive        TS          -5709.928
# 2           Inactive  Inactive  Inactive      INT1          -5709.939
# 3           Inactive  Inactive  Inactive       TS1          -5709.895
# 4           Inactive  Inactive  Inactive      INT2          -5709.897
# 5           Inactive  Inactive  Inactive       TS2          -5709.888
# 6           Inactive  Inactive  Inactive      INT3          -5709.897
# 7           Inactive  Inactive  Inactive       TS3          -5709.886
# 8           Inactive  Inactive  Inactive      INT4          -5709.893
# 9             Active    Active    Active        ES          -5709.973
# 10            Active    Active    Active        TS          -5709.947
# 11            Active    Active    Active      INT1          -5709.971
# ...

# %%
almo_eda_data = pd.read_csv('almo-eda_data.csv',header=4)
almo_eda_data
# Out:
#                Model   fGln123     Val51 Structure  ∆ELEC (kcal/mol)  \
# 0           Inactive  Inactive  Inactive        ES            -35.39
# 1           Inactive  Inactive  Inactive       TS1            -31.00
# 2           Inactive  Inactive  Inactive       TS2            -30.30
# 3           Inactive  Inactive  Inactive       TS3            -31.90
# 4             Active    Active    Active        ES            -88.37
# 5             Active    Active    Active       TS1            -86.60
# 6             Active    Active    Active       TS2            -86.30
# 7             Active    Active    Active       TS3            -87.20
# 8   Inactive fGln123  Inactive    Active        ES            -11.11
# 9   Inactive fGln123  Inactive    Active       TS1             -9.90
# 10  Inactive fGln123  Inactive    Active       TS2             -9.50
# 11  Inactive fGln123  Inactive    Active       TS3             -9.30
# 12    Inactive Val51    Active  Inactive        ES            -89.54
# ...

# %%
nbo_data = pd.read_csv('nbo_data.csv',header=3)
nbo_data
# Out:
#                Model   fGln123     Val51 Structure Residue  \
# 0             Active    Active    Active       TS1   Val51
# 1             Active    Active    Active       TS1   Gly52
# 2             Active    Active    Active       TS1   Leu85
# 3             Active    Active    Active       TS2   Val51
# 4             Active    Active    Active       TS2   Gly52
# 5             Active    Active    Active       TS2   Leu85
# 6             Active    Active    Active       TS3   Val51
# 7             Active    Active    Active       TS3   Gly52
# 8             Active    Active    Active       TS3   Leu85
# 9   Inactive fGln123  Inactive    Active       TS1   Val51
# 10  Inactive fGln123  Inactive    Active       TS1   Gly52
# 11  Inactive fGln123  Inactive    Active       TS1   Leu85
# 12  Inactive fGln123  Inactive    Active       TS2   Val51
# 13  Inactive fGln123  Inactive    Active       TS2   Gly52
# 14  Inactive fGln123  Inactive    Active       TS2   Leu85
# ...
